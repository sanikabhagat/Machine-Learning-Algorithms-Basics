# %% [markdown]
# # Logistic Regression Basics

# %% [markdown]
# ### What is Logistic Regression?
#
# Logistic regression is a classification algorithm used to assign observations to a discrete set of classes. Unlike linear regression which outputs continuous number values, logistic regression transforms its output using the logistic sigmoid function to return a probability value which can then be mapped to two or more discrete classes

# %% [markdown]
# ### Comparison to linear regression
#
# Given data on time spent studying and exam scores. Linear Regression and logistic regression can predict different things:
#
# Linear Regression could help us predict the student’s test score on a scale of 0 - 100. Linear regression predictions are continuous (numbers in a range).
#
# Logistic Regression could help use predict whether the student passed or failed. Logistic regression predictions are discrete (only specific values or categories are allowed). We can also view probability scores underlying the model’s classifications.

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# The logistic regression is used when we want the results in a probablity from 0 to 1 belonging in the 1 class
# We can set a cutoff at 0.5, anything below it results in class 0, anythig above is class 1

# %% [markdown]
# ### Model Evaluation
#
# After you train a logistic regression model on some training data, you will evaluate your model's performance on some test data
#
# You can usea confusion matrix to evaluate classification models

# %% [markdown]
# ### Confusion Matrix
#
# A confusion matrix is a table that is often used to describe the performance of a classification model on a test data for which true values are already known

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# ### Basic Terminology of Confusion Matrix
#
# 1. True Positives: True Positives are the cases in which we predicted yes and the actual value is yes
# 2. True Negatives: True Negatives are the cases in which we predicted no and the actual value is no
# 3. False Positives: False Positives are the cases in which we predicted yes but the actual value is no. This is also kknown as type 1 error
# 4. False Negatives: False Negatives are the cases in which we predicted no but the actual value is yes. This is also known as type 2 error

# %% [markdown]
# ### Accuracy Rate (Overall, how oftern is this correct?)
#
# Formula : (TP+TN)/Total

# %% [markdown]
# ### Misclassification Rate / Error Rate  (Overall, how oftern is this wrong?)
#
# Formula : (FP+FN)/Total

# %% [markdown]
# ### False Positives and False Negatives Example

# %% [markdown]
# ![Capture1.PNG](attachment:Capture1.PNG)
